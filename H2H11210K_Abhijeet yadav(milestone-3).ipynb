# %% [markdown]
# ### Milestone 2: Abhijeet Yadav 20052000 H2H11210K

# %%
## Milestone 3 - Feature Engineering and Selection

# %%
# 1. Check for the outliers in the “amount_in_usd” column and replace the
#outliers with appropriate values, discussed in the sessions.

sns.boxplot(data=df, y='amount_in_usd')
plt.title('Box Plot of Amount in USD')
plt.show()

# %%
sns.scatterplot(data=df, x=range(len(df)), y='amount_in_usd')
plt.title('Check outliers of Amount in USD')
plt.show()

# %%
Q1 = np.percentile(df['amount_in_usd'], 25)
Q3 = np.percentile(df['amount_in_usd'], 75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
outliers = (df['amount_in_usd'] < lower_bound) | (df['amount_in_usd'] > upper_bound)

outliers
# Out:
# 0          False
# 1          False
# 2           True
# 3          False
# 4          False
#            ...
# 1101920     True
# 1101921    False
# 1101922    False
# 1101923    False
# 1101924     True
# Name: amount_in_usd, Length: 1074783, dtype: bool

# %%
sns.boxplot(data=df, y='amount_in_usd')
plt.title('Box Plot of Amount in USD')
plt.show()

# %%
# 2. Label encoding or One hot Encoding on all the categorical columns

from sklearn.preprocessing import LabelEncoder

category=[]
continuous=[]
for i in df.columns:
    if (df[i].dtype=='object' or df[i].dtype=='category'):
        category.append(i)
    elif (df[i].dtype=='float64' or df[i].dtype=='int64'):
        continuous.append(i)
        
print(category)
# Out:
# ['DISTRIBUTION_CHANNEL', 'DIVISION', 'RELEASED_CREDIT_VALUE', 'PURCHASE_ORDER_TYPE', 'CREDIT_CONTROL_AREA', 'ORDER_CURRENCY', 'CREDIT_STATUS', 'unique_cust_id']

# %%
le=LabelEncoder()
for i in category:
    df[i]=df[i].astype(str)
    df[i]=le.fit_transform(df[i])

df
# Out:
#          CUSTOMER_ORDER_ID  SALES_ORG  DISTRIBUTION_CHANNEL  DIVISION  \
# 0                946851639       3537                   232         1
# 1                963432061       3449                   135         1
# 2                971991639       3238                   141         1
# 3                754349803       3911                   228         1
# 4                930253442       2381                    82         1
# ...                    ...        ...                   ...       ...
# 1101920          853605710       2498                    79         1
# 1101921          998890898       4509                    10         1
# 1101922          983330221       3951                   151         1
# 1101923          926668029       3235                   167         1
# 1101924          921701000       2968                   156         1
#
#          RELEASED_CREDIT_VALUE  PURCHASE_ORDER_TYPE  COMPANY_CODE  \
# 0                            1                    0          3220
# 1                            1                    0          3220
# 2                        43496                  204          3260
# 3                         7852                  255          3290
# 4                            1                  255          3290
# ...                        ...                  ...           ...
# 1101920                      1                  306          4260
# 1101921                      1                  306          4260
# 1101922                      1                  306          4260
# 1101923                      1                  306          4260
# 1101924                      1                  306          4260
#
#         ORDER_CREATION_DATE  ORDER_CREATION_TIME  CREDIT_CONTROL_AREA  \
# 0                2022-01-01                43012                    5
# 1                2022-01-01                43114                    2
# 2                2022-01-01               110019                    0
# 3                2022-01-01               153013                    5
# 4                2022-01-01               160020                    4
# ...                     ...                  ...                  ...
# 1101920          2022-06-01                74357                    1
# 1101921          2022-06-01                84052                    3
# 1101922          2022-06-01                85322                    0
# 1101923          2022-06-01                90538                    7
# 1101924          2022-06-01               113357                    1
#
#          SOLD_TO_PARTY  ORDER_AMOUNT REQUESTED_DELIVERY_DATE  ORDER_CURRENCY  \
# 0            756141537        954.61              2022-01-13               6
# 1            798847812        787.36              2022-01-11               6
# 2            960984659      67493.46              2022-01-12               6
# 3            925857642       1405.54              2022-01-06               6
# 4            947942786          0.00              2022-01-06               6
# ...                ...           ...                     ...             ...
# 1101920      946056501       4415.19              2022-06-01              18
# 1101921      894775488          0.00              2022-06-01              18
# 1101922      909729781          0.00              2022-06-01              18
# 1101923      940836817          0.00              2022-06-01              18
# 1101924      754385277       4415.19              2022-06-01              18
#
#          CREDIT_STATUS  CUSTOMER_NUMBER  amount_in_usd  unique_cust_id
# 0                    3         12311807     892.158879            6608
# 1                    3         12311807     735.850467            6608
# 2                    2         12118758   63078.000000            4405
# 3                    2       1210499770    1313.588785            4059
# 4                    1       1210351400       0.000000            2919
# ...                ...              ...            ...             ...
# 1101920              3       1210331804    5966.472973            2782
# 1101921              3       1210331804       0.000000            2782
# 1101922              3       1210331811       0.000000            2784
# 1101923              3       1210331811       0.000000            2784
# 1101924              3       1210331804    5966.472973            2782
#
# [1074783 rows x 18 columns]

# %%
# 3. Log Transformations on continuous columns

print(continuous)
# Out:
# ['CUSTOMER_ORDER_ID', 'SALES_ORG', 'COMPANY_CODE', 'ORDER_CREATION_TIME', 'SOLD_TO_PARTY', 'ORDER_AMOUNT', 'CUSTOMER_NUMBER', 'amount_in_usd']

# %%
for col in continuous:
    df[col] = df[col].apply(lambda x: np.log(x))
    
df[continuous]
# Out:
#          CUSTOMER_ORDER_ID  SALES_ORG  COMPANY_CODE  ORDER_CREATION_TIME  \
# 0                20.668653   8.171034      8.077137            10.669234
# 1                20.686013   8.145840      8.077137            10.671603
# 2                20.694858   8.082711      8.089482            11.608408
# 3                20.441367   8.271548      8.098643            11.938278
# 4                20.650968   7.775276      8.098643            11.983054
# ...                    ...        ...           ...                  ...
# 1101920          20.564980   7.823246      8.357024            11.216633
# 1101921          20.722156   8.413831      8.357024            11.339191
# 1101922          20.706456   8.281724      8.357024            11.354188
# 1101923          20.647106   8.081784      8.357024            11.413525
# 1101924          20.641731   7.995644      8.357024            11.638297
#
#          SOLD_TO_PARTY  ORDER_AMOUNT  CUSTOMER_NUMBER  amount_in_usd
# 0            20.443739      6.861303        16.326069       6.793644
# 1            20.498681      6.668686        16.326069       6.601027
# 2            20.683469     11.119786        16.310265      11.052127
# 3            20.646231      7.248177        20.914299       7.180518
# 4            20.669805          -inf        20.914177           -inf
# ...                ...           ...              ...            ...
# 1101920      20.667813      8.392806        20.914160       8.693911
# 1101921      20.612083          -inf        20.914160           -inf
# 1101922      20.628658          -inf        20.914160           -inf
# 1101923      20.662280          -inf        20.914160           -inf
# 1101924      20.441414      8.392806        20.914160       8.693911
#
# [1074783 rows x 8 columns]

# %%
# 4. Try to extract new features by grouping existing columns

grouped_data = df.groupby('SALES_ORG').agg({
    'ORDER_AMOUNT': ['mean'],
    'RELEASED_CREDIT_VALUE': ['sum'],
    'CUSTOMER_NUMBER': ['nunique'],
    'amount_in_usd': ['max']
}).reset_index()

grouped_data.columns = ['SALES_ORG', 'AVG_ORDER_AMOUNT', 'TOTAL_CREDIT_VALUE', 'UNIQUE_CUSTOMER', 'MAX_AMOUNT_IN_USD']

grouped_data
# Out:
#       SALES_ORG  AVG_ORDER_AMOUNT  TOTAL_CREDIT_VALUE  UNIQUE_CUSTOMER  \
# 0      7.649693               NaN              609429              141
# 1      7.650169               NaN              723167              129
# 2      7.650645               NaN              594668              116
# 3      7.651120               NaN              667986              124
# 4      7.651596               NaN              806552              137
# ...         ...               ...                 ...              ...
# 2406   8.413165               NaN              613023              143
# 2407   8.413387               NaN              620833              122
# 2408   8.413609               NaN              775251              139
# 2409   8.413831               NaN              487248              146
# 2410   8.414052               NaN              634880              138
#
#       MAX_AMOUNT_IN_USD
# 0             20.113511
# 1             20.662564
# 2             15.438588
# 3             15.551612
# 4             14.169593
# ...                 ...
# 2406          16.039052
# 2407          21.736027
# 2408          21.071276
# 2409          13.765306
# 2410          12.158821
#
# [2411 rows x 5 columns]

# %%
# 5. Create a heatmap to find correlation between the columns

plt.figure(figsize=(16,16))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm', fmt=".4f")
plt.title('Correlation Heatmap', fontsize='20')
plt.show()

# %%
# 6. Try to identify important or relevant columns for feature extraction

cmat = df.corr().abs()

threshold = 0.6

high_corr_columns = cmat[cmat > threshold].stack().reset_index()
high_corr_columns = high_corr_columns[high_corr_columns['level_0'] != high_corr_columns['level_1']]

relevant_columns = pd.unique(high_corr_columns[['level_0', 'level_1']].values.ravel('K'))

print(high_corr_columns)

print("\nRelevant Columns:\n",relevant_columns)
# Out:
#                 level_0              level_1         0
# 6   PURCHASE_ORDER_TYPE       ORDER_CURRENCY  0.838794
# 12         ORDER_AMOUNT        amount_in_usd  0.972965
# 13       ORDER_CURRENCY  PURCHASE_ORDER_TYPE  0.838794
# 17        amount_in_usd         ORDER_AMOUNT  0.972965
#
# Relevant Columns:
#  ['PURCHASE_ORDER_TYPE' 'ORDER_AMOUNT' 'ORDER_CURRENCY' 'amount_in_usd']
